# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Постройте топ фильмов в категориях Action и Comedy

# %%
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')

# %%
movies.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247

# %%
tags.head(2)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996

# %%
rating_set = set(ratings['movieId'].unique())
movie_set = set(movies['movieId'].unique())
tags_set = set(tags['movieId'].unique())

# %%
len(rating_set), len(movie_set), len(tags_set)
# Out:
# (9724, 9742, 1572)

# %%
rating_set.issubset(movie_set)
# Out:
# True

# %%
tags_set.issubset(movie_set)
# Out:
# True

# %% [markdown]
# Фильмов с оценками немного меньше, чем фильмов без. Фильмов, которым проставили тэги, гораздо меньше, чем фильмов без тэгов.

# %%
def normed_user_rate_func(x):
    """
    Функция для нормирования оценки пользователя
    """
    if x.max() != x.min():
        return (x - x.min())/(x.max() - x.min())
    else:
        return 1
    
ratings['normed_user_rating'] = ratings.groupby('userId', sort=False)['rating'].transform(normed_user_rate_func)

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp  normed_user_rating
# 0       1        1     4.0  964982703                0.75
# 1       1        3     4.0  964981247                0.75
# 2       1        6     4.0  964982224                0.75
# 3       1       47     5.0  964983815                1.00
# 4       1       50     5.0  964982931                1.00

# %%
# количество оценок по фильмам
movies_rating_count = ratings.groupby('movieId', sort=False)['rating'].count()
# средняя нормированная оценка пользователя для каждого фильма
movies_mean_rating = ratings.groupby('movieId', sort=False)['normed_user_rating'].mean()

# %%
# среднее количество оценок фильма
mean_num_rate = movies_rating_count.mean()
# медианное количество оценок фильма
median_num_rate = movies_rating_count.median()
min_num_rate = movies_rating_count.min()
max_num_rate = movies_rating_count.max()
std_num_rate = movies_rating_count.std()

# %%
mean_num_rate, median_num_rate, min_num_rate, max_num_rate, std_num_rate
# Out:
# (10.369806663924312, 3.0, 1, 329, 22.401004809608246)

# %%
# нормированная средняя оценка фильма
movies_mean_normed_rating = pd.DataFrame(movies_mean_rating*
        (movies_rating_count - mean_num_rate)/std_num_rate, columns=['movie_normed_mean_rating'])

# %%
movies_mean_normed_rating.head()
# Out:
#          movie_normed_mean_rating
# movieId
# 1                        6.584792
# 3                        0.977352
# 6                        2.961041
# 47                       6.282596
# 50                       6.902174

# %%
movies = pd.merge(movies, movies_mean_normed_rating, left_on='movieId', right_index=True)

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  movie_normed_mean_rating
# 0  Adventure|Animation|Children|Comedy|Fantasy                  6.584792
# 1                   Adventure|Children|Fantasy                  2.674611
# 2                               Comedy|Romance                  0.977352
# 3                         Comedy|Drama|Romance                 -0.042383
# 4                                       Comedy                  0.748352

# %%
# топ 20 фильмов без привязки к жанру (по нормированному рейтингу)
movies.sort_values('movie_normed_mean_rating', ascending=False).head(20)
# Out:
#       movieId                                              title  \
# 277       318                   Shawshank Redemption, The (1994)
# 314       356                                Forrest Gump (1994)
# 257       296                                Pulp Fiction (1994)
# 1939     2571                                 Matrix, The (1999)
# 510       593                   Silence of the Lambs, The (1991)
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 2226     2959                                  Fight Club (1999)
# 97        110                                  Braveheart (1995)
# 461       527                            Schindler's List (1993)
# 898      1196  Star Wars: Episode V - The Empire Strikes Back...
# 507       589                  Terminator 2: Judgment Day (1991)
# 46         50                         Usual Suspects, The (1995)
# 418       480                               Jurassic Park (1993)
# 900      1198  Raiders of the Lost Ark (Indiana Jones and the...
# 659       858                              Godfather, The (1972)
# 2145     2858                             American Beauty (1999)
# 0           1                                   Toy Story (1995)
# 911      1210  Star Wars: Episode VI - Return of the Jedi (1983)
# 3638     4993  Lord of the Rings: The Fellowship of the Ring,...
# 43         47                        Seven (a.k.a. Se7en) (1995)
#
#                                            genres  movie_normed_mean_rating
# 277                                   Crime|Drama                 11.620828
# 314                      Comedy|Drama|Romance|War                 11.159282
# 257                   Comedy|Crime|Drama|Thriller                 10.375570
# 1939                       Action|Sci-Fi|Thriller                  9.505250
# 510                         Crime|Horror|Thriller                  9.455111
# 224                       Action|Adventure|Sci-Fi                  8.634377
# 2226                  Action|Crime|Drama|Thriller                  7.568651
# 97                               Action|Drama|War                  7.554489
# 461                                     Drama|War                  7.489698
# 898                       Action|Adventure|Sci-Fi                  7.155559
# 507                                 Action|Sci-Fi                  6.956110
# 46                         Crime|Mystery|Thriller                  6.902174
# 418              Action|Adventure|Sci-Fi|Thriller                  6.860897
# 900                              Action|Adventure                  6.803965
# 659                                   Crime|Drama                  6.632262
# 2145                                Drama|Romance                  6.586135
# 0     Adventure|Animation|Children|Comedy|Fantasy                  6.584792
# 911                       Action|Adventure|Sci-Fi                  6.494378
# 3638                            Adventure|Fantasy                  6.481071
# 43                               Mystery|Thriller                  6.282596

# %%
# количество тэгов для каждого фильма
movies_tag_count = pd.DataFrame(tags.groupby('movieId')['tag'].count())
movies_tag_count.columns = ['num_of_tags']

# %%
movies_tag_count.head()
# Out:
#          num_of_tags
# movieId
# 1                  3
# 2                  4
# 3                  2
# 5                  2
# 7                  1

# %%
# основные статистики по количеству тэгов
mean_tags_num = movies_tag_count.mean()[0]
median_tags_num = movies_tag_count.median()[0]
min_tags_num = movies_tag_count.min()[0]
max_tags_num = movies_tag_count.max()[0]
std_tags_num = movies_tag_count.std()[0]

# %%
mean_tags_num, median_tags_num, min_tags_num, max_tags_num, std_tags_num
# Out:
# (2.3428753180661577, 1.0, 1, 181, 5.562342135655902)

# %%
movies_tag_count = pd.merge(movies_tag_count, pd.DataFrame(ratings.groupby('movieId', sort=False)['rating'].mean()), left_index=True, right_index=True)

# %%
movies_tag_count.head()
# Out:
#          num_of_tags    rating
# movieId
# 1                  3  3.920930
# 2                  4  3.431818
# 3                  2  3.259615
# 5                  2  3.071429
# 7                  1  3.185185

# %%
movies_tag_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1554 entries, 1 to 193565
# Data columns (total 2 columns):
# num_of_tags    1554 non-null int64
# rating         1554 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 36.4 KB

# %%
# нормированная по количеству тэгов средний рейтинг фильма.
movies_tag_count['normed_by_tags_movie_rating'] = (movies_tag_count['rating']*
        (movies_tag_count['num_of_tags'] - mean_tags_num)/std_tags_num)

# %%
movies_tag_count.head()
# Out:
#          num_of_tags    rating  normed_by_tags_movie_rating
# movieId
# 1                  3  3.920930                     0.463211
# 2                  4  3.431818                     1.022402
# 3                  2  3.259615                    -0.200930
# 5                  2  3.071429                    -0.189330
# 7                  1  3.185185                    -0.768976

# %%
movies_tags = pd.merge(movies, movies_tag_count, left_on='movieId', right_index=True)

# %%
movies_tags.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 4        5  Father of the Bride Part II (1995)
# 6        7                      Sabrina (1995)
#
#                                         genres  movie_normed_mean_rating  \
# 0  Adventure|Animation|Children|Comedy|Fantasy                  6.584792
# 1                   Adventure|Children|Fantasy                  2.674611
# 2                               Comedy|Romance                  0.977352
# 4                                       Comedy                  0.748352
# 6                               Comedy|Romance                  0.947953
#
#    num_of_tags    rating  normed_by_tags_movie_rating
# 0            3  3.920930                     0.463211
# 1            4  3.431818                     1.022402
# 2            2  3.259615                    -0.200930
# 4            2  3.071429                    -0.189330
# 6            1  3.185185                    -0.768976

# %%
# топ 20 фильмов без привязки к жанру (рейтинг нормирован по количеству тэгов)
movies_tags.sort_values('normed_by_tags_movie_rating', ascending=False).head(20)
# Out:
#       movieId                                              title  \
# 257       296                                Pulp Fiction (1994)
# 2226     2959                                  Fight Club (1999)
# 706       924                       2001: A Space Odyssey (1968)
# 4909     7361       Eternal Sunshine of the Spotless Mind (2004)
# 254       293  Léon: The Professional (a.k.a. The Professiona...
# 1298     1732                           Big Lebowski, The (1998)
# 3562     4878                                Donnie Darko (2001)
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 7372    79132                                   Inception (2010)
# 3087     4144      In the Mood For Love (Fa yeung nin wa) (2000)
# 1402     1921                                          Pi (1998)
# 7212    72998                                      Avatar (2009)
# 2738     3676                                  Eraserhead (1977)
# 8693   122912             Avengers: Infinity War - Part I (2018)
# 8915   135536                               Suicide Squad (2016)
# 7166    71899                                Mary and Max (2009)
# 3141     4226                                     Memento (2000)
# 474       541                                Blade Runner (1982)
# 7039    68954                                          Up (2009)
# 4015     5673                            Punch-Drunk Love (2002)
#
#                                                genres  \
# 257                       Comedy|Crime|Drama|Thriller
# 2226                      Action|Crime|Drama|Thriller
# 706                            Adventure|Drama|Sci-Fi
# 4909                             Drama|Romance|Sci-Fi
# 254                       Action|Crime|Drama|Thriller
# 1298                                     Comedy|Crime
# 3562                    Drama|Mystery|Sci-Fi|Thriller
# 224                           Action|Adventure|Sci-Fi
# 7372  Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX
# 3087                                    Drama|Romance
# 1402                            Drama|Sci-Fi|Thriller
# 7212                     Action|Adventure|Sci-Fi|IMAX
# 2738                                     Drama|Horror
# 8693                          Action|Adventure|Sci-Fi
# 8915                              Action|Crime|Sci-Fi
# 7166                           Animation|Comedy|Drama
# 3141                                 Mystery|Thriller
# 474                            Action|Sci-Fi|Thriller
# 7039               Adventure|Animation|Children|Drama
# 4015                             Comedy|Drama|Romance
#
#       movie_normed_mean_rating  num_of_tags    rating  \
# 257                  10.375570          181  4.197068
# 2226                  7.568651           54  4.272936
# 706                   3.230359           41  3.894495
# 4909                  4.281520           34  4.160305
# 254                   4.061539           35  4.018797
# 1298                  3.145089           32  3.924528
# 3562                  3.313038           29  3.981651
# 224                   8.634377           26  4.231076
# 7372                  4.453425           26  4.066434
# 3087                  0.133599           18  4.214286
# 1402                  1.171702           17  3.851064
# 7212                  2.523566           18  3.603093
# 2738                 -0.011785           17  3.750000
# 8693                  0.087383           15  4.000000
# 8915                  0.038998           19  2.916667
# 7166                 -0.013230           13  4.200000
# 3141                  5.240968           13  4.122642
# 474                   3.962231           13  4.100806
# 7039                  3.157503           13  4.004762
# 4015                  0.681031           13  3.621212
#
#       normed_by_tags_movie_rating
# 257                    134.805834
# 2226                    39.682488
# 706                     27.065936
# 4909                    23.677671
# 254                     23.594801
# 1298                    20.924679
# 3562                    19.081778
# 224                     17.995133
# 7372                    17.294895
# 3087                    11.862556
# 1402                    10.147798
# 7212                    10.142144
# 2738                     9.881488
# 8693                     9.102011
# 8915                     8.734321
# 7166                     8.046956
# 3141                     7.898742
# 474                      7.856907
# 7039                     7.672891
# 4015                     6.938032

# %% [markdown]
# При использовании оценки нормированной по количеству тэгов в топ попадают не только популярные фильмы но и артхаусное кино, которое понравиться далеко не всем (такие как: Голова-ластик, Донни Дарко, 2001 космическая одиссея и др.).

# %% [markdown]
# Теперь посмотрим на топ фильмов по жанрам экшн и комедия.

# %%
actions = movies[movies['genres'].str.lower().str.contains('action')]
comedies = movies[movies['genres'].str.lower().str.contains('comedy')]

actions_tags = movies_tags[movies_tags['genres'].str.lower().str.contains('action')]
comedies_tags = movies_tags[movies_tags['genres'].str.lower().str.contains('comedy')]

# %% [markdown]
# ### Топ 20 экшн фильмов согласно нормированному рейтингу

# %%
actions.sort_values('movie_normed_mean_rating', ascending=False).head(20)
# Out:
#       movieId                                              title  \
# 1939     2571                                 Matrix, The (1999)
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 2226     2959                                  Fight Club (1999)
# 97        110                                  Braveheart (1995)
# 898      1196  Star Wars: Episode V - The Empire Strikes Back...
# 507       589                  Terminator 2: Judgment Day (1991)
# 418       480                               Jurassic Park (1993)
# 900      1198  Raiders of the Lost Ark (Indiana Jones and the...
# 911      1210  Star Wars: Episode VI - Return of the Jedi (1983)
# 1503     2028                         Saving Private Ryan (1998)
# 4800     7153  Lord of the Rings: The Return of the King, The...
# 2674     3578                                   Gladiator (2000)
# 615       780               Independence Day (a.k.a. ID4) (1996)
# 6710    58559                            Dark Knight, The (2008)
# 899      1197                         Princess Bride, The (1987)
# 509       592                                      Batman (1989)
# 337       380                                   True Lies (1994)
# 7372    79132                                   Inception (2010)
# 334       377                                       Speed (1994)
# 990      1291          Indiana Jones and the Last Crusade (1989)
#
#                                                genres  \
# 1939                           Action|Sci-Fi|Thriller
# 224                           Action|Adventure|Sci-Fi
# 2226                      Action|Crime|Drama|Thriller
# 97                                   Action|Drama|War
# 898                           Action|Adventure|Sci-Fi
# 507                                     Action|Sci-Fi
# 418                  Action|Adventure|Sci-Fi|Thriller
# 900                                  Action|Adventure
# 911                           Action|Adventure|Sci-Fi
# 1503                                 Action|Drama|War
# 4800                   Action|Adventure|Drama|Fantasy
# 2674                           Action|Adventure|Drama
# 615                  Action|Adventure|Sci-Fi|Thriller
# 6710                          Action|Crime|Drama|IMAX
# 899           Action|Adventure|Comedy|Fantasy|Romance
# 509                             Action|Crime|Thriller
# 337          Action|Adventure|Comedy|Romance|Thriller
# 7372  Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX
# 334                           Action|Romance|Thriller
# 990                                  Action|Adventure
#
#       movie_normed_mean_rating
# 1939                  9.505250
# 224                   8.634377
# 2226                  7.568651
# 97                    7.554489
# 898                   7.155559
# 507                   6.956110
# 418                   6.860897
# 900                   6.803965
# 911                   6.494378
# 1503                  6.176242
# 4800                  6.043177
# 2674                  5.283458
# 615                   5.177877
# 6710                  4.980639
# 899                   4.749260
# 509                   4.517644
# 337                   4.464202
# 7372                  4.453425
# 334                   4.446174
# 990                   4.406499

# %% [markdown]
# ### Топ 20 комедийных фильмов согласно нормированному рейтингу

# %%
comedies.sort_values('movie_normed_mean_rating', ascending=False).head(20)
# Out:
#       movieId                                              title  \
# 314       356                                Forrest Gump (1994)
# 257       296                                Pulp Fiction (1994)
# 0           1                                   Toy Story (1995)
# 520       608                                       Fargo (1996)
# 969      1270                          Back to the Future (1985)
# 506       588                                     Aladdin (1992)
# 3194     4306                                       Shrek (2001)
# 899      1197                         Princess Bride, The (1987)
# 337       380                                   True Lies (1994)
# 863      1136             Monty Python and the Holy Grail (1975)
# 964      1265                               Groundhog Day (1993)
# 1183     1580                   Men in Black (a.k.a. MIB) (1997)
# 4427     6539  Pirates of the Caribbean: The Curse of the Bla...
# 4360     6377                                Finding Nemo (2003)
# 3568     4886                              Monsters, Inc. (2001)
# 3622     4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 1267     1682                            Truman Show, The (1998)
# 5374     8961                            Incredibles, The (2004)
# 436       500                              Mrs. Doubtfire (1993)
# 325       367                                   Mask, The (1994)
#
#                                                  genres  \
# 314                            Comedy|Drama|Romance|War
# 257                         Comedy|Crime|Drama|Thriller
# 0           Adventure|Animation|Children|Comedy|Fantasy
# 520                         Comedy|Crime|Drama|Thriller
# 969                             Adventure|Comedy|Sci-Fi
# 506         Adventure|Animation|Children|Comedy|Musical
# 3194  Adventure|Animation|Children|Comedy|Fantasy|Ro...
# 899             Action|Adventure|Comedy|Fantasy|Romance
# 337            Action|Adventure|Comedy|Romance|Thriller
# 863                            Adventure|Comedy|Fantasy
# 964                              Comedy|Fantasy|Romance
# 1183                               Action|Comedy|Sci-Fi
# 4427                    Action|Adventure|Comedy|Fantasy
# 4360                Adventure|Animation|Children|Comedy
# 3568        Adventure|Animation|Children|Comedy|Fantasy
# 3622                                     Comedy|Romance
# 1267                                Comedy|Drama|Sci-Fi
# 5374         Action|Adventure|Animation|Children|Comedy
# 436                                        Comedy|Drama
# 325                         Action|Comedy|Crime|Fantasy
#
#       movie_normed_mean_rating
# 314                  11.159282
# 257                  10.375570
# 0                     6.584792
# 520                   5.908061
# 969                   5.466645
# 506                   5.269003
# 3194                  5.169215
# 899                   4.749260
# 337                   4.464202
# 863                   4.445469
# 964                   4.373805
# 1183                  4.326251
# 4427                  4.307408
# 4360                  4.286042
# 3568                  3.934981
# 3622                  3.910091
# 1267                  3.660350
# 5374                  3.657361
# 436                   3.513415
# 325                   3.443506

# %% [markdown]
# ### Топ 20 экшн фильмов согласно нормированному по количеству тэгов рейтингу

# %%
actions_tags.sort_values('normed_by_tags_movie_rating', ascending=False).head(20)
# Out:
#       movieId                                              title  \
# 2226     2959                                  Fight Club (1999)
# 254       293  Léon: The Professional (a.k.a. The Professiona...
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 7372    79132                                   Inception (2010)
# 7212    72998                                      Avatar (2009)
# 8693   122912             Avengers: Infinity War - Part I (2018)
# 8915   135536                               Suicide Squad (2016)
# 474       541                                Blade Runner (1982)
# 8063    99114                            Django Unchained (2012)
# 898      1196  Star Wars: Episode V - The Empire Strikes Back...
# 4800     7153  Lord of the Rings: The Return of the King, The...
# 7030    68791                        Terminator Salvation (2009)
# 2636     3527                                    Predator (1987)
# 97        110                                  Braveheart (1995)
# 4705     7022             Battle Royale (Batoru rowaiaru) (2000)
# 902      1200                                      Aliens (1986)
# 7018    68358                                   Star Trek (2009)
# 8537   115149                                   John Wick (2014)
# 900      1198  Raiders of the Lost Ark (Indiana Jones and the...
# 9461   168248                      John Wick: Chapter Two (2017)
#
#                                                genres  \
# 2226                      Action|Crime|Drama|Thriller
# 254                       Action|Crime|Drama|Thriller
# 224                           Action|Adventure|Sci-Fi
# 7372  Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX
# 7212                     Action|Adventure|Sci-Fi|IMAX
# 8693                          Action|Adventure|Sci-Fi
# 8915                              Action|Crime|Sci-Fi
# 474                            Action|Sci-Fi|Thriller
# 8063                             Action|Drama|Western
# 898                           Action|Adventure|Sci-Fi
# 4800                   Action|Adventure|Drama|Fantasy
# 7030                 Action|Adventure|Sci-Fi|Thriller
# 2636                           Action|Sci-Fi|Thriller
# 97                                   Action|Drama|War
# 4705                     Action|Drama|Horror|Thriller
# 902                    Action|Adventure|Horror|Sci-Fi
# 7018                     Action|Adventure|Sci-Fi|IMAX
# 8537                                  Action|Thriller
# 900                                  Action|Adventure
# 9461                            Action|Crime|Thriller
#
#       movie_normed_mean_rating  num_of_tags    rating  \
# 2226                  7.568651           54  4.272936
# 254                   4.061539           35  4.018797
# 224                   8.634377           26  4.231076
# 7372                  4.453425           26  4.066434
# 7212                  2.523566           18  3.603093
# 8693                  0.087383           15  4.000000
# 8915                  0.038998           19  2.916667
# 474                   3.962231           13  4.100806
# 8063                  1.962576           12  3.943662
# 898                   7.155559           10  4.215640
# 4800                  6.043177           10  4.118919
# 7030                  0.199520           12  3.250000
# 2636                  1.488890           11  3.581967
# 97                    7.554489           10  4.031646
# 4705                  0.657811           10  3.933333
# 902                   3.846565            9  3.964286
# 7018                  1.577971            9  3.864407
# 8537                  0.597007            9  3.844828
# 900                   6.803965            8  4.207500
# 9461                 -0.120882            8  4.142857
#
#       normed_by_tags_movie_rating
# 2226                    39.682488
# 254                     23.594801
# 224                     17.995133
# 7372                    17.294895
# 7212                    10.142144
# 8693                     9.102011
# 8915                     8.734321
# 474                      7.856907
# 8063                     6.846834
# 898                      5.803253
# 4800                     5.670107
# 7030                     5.642525
# 2636                     5.574906
# 97                       5.549967
# 4705                     5.414630
# 902                      4.744538
# 7018                     4.625001
# 8537                     4.601568
# 900                      4.279196
# 9461                     4.213452

# %% [markdown]
# ### Топ 20 комедийных фильмов согласно нормированному по количеству тэгов рейтингу

# %%
comedies_tags.sort_values('normed_by_tags_movie_rating', ascending=False).head(20)
# Out:
#       movieId                                              title  \
# 257       296                                Pulp Fiction (1994)
# 1298     1732                           Big Lebowski, The (1998)
# 7166    71899                                Mary and Max (2009)
# 4015     5673                            Punch-Drunk Love (2002)
# 602       750  Dr. Strangelove or: How I Learned to Stop Worr...
# 6836    61323                          Burn After Reading (2008)
# 314       356                                Forrest Gump (1994)
# 6676    57669                                   In Bruges (2008)
# 1730     2324         Life Is Beautiful (La Vita è bella) (1997)
# 2028     2700        South Park: Bigger, Longer and Uncut (1999)
# 2355     3114                                 Toy Story 2 (1999)
# 7075    69757                        (500) Days of Summer (2009)
# 7655    88405                       Friends with Benefits (2011)
# 6801    60756                               Step Brothers (2008)
# 6987    67087                             I Love You, Man (2009)
# 2031     2706                                American Pie (1999)
# 6016    38061                         Kiss Kiss Bang Bang (2005)
# 8357   108932                              The Lego Movie (2014)
# 6537    54503                                    Superbad (2007)
# 5263     8641       Anchorman: The Legend of Ron Burgundy (2004)
#
#                                                  genres  \
# 257                         Comedy|Crime|Drama|Thriller
# 1298                                       Comedy|Crime
# 7166                             Animation|Comedy|Drama
# 4015                               Comedy|Drama|Romance
# 602                                          Comedy|War
# 6836                                 Comedy|Crime|Drama
# 314                            Comedy|Drama|Romance|War
# 6676                        Comedy|Crime|Drama|Thriller
# 1730                           Comedy|Drama|Romance|War
# 2028                           Animation|Comedy|Musical
# 2355        Adventure|Animation|Children|Comedy|Fantasy
# 7075                               Comedy|Drama|Romance
# 7655                                     Comedy|Romance
# 6801                                             Comedy
# 6987                                             Comedy
# 2031                                     Comedy|Romance
# 6016                      Comedy|Crime|Mystery|Thriller
# 8357  Action|Adventure|Animation|Children|Comedy|Fan...
# 6537                                             Comedy
# 5263                                             Comedy
#
#       movie_normed_mean_rating  num_of_tags    rating  \
# 257                  10.375570          181  4.197068
# 1298                  3.145089           32  3.924528
# 7166                 -0.013230           13  4.200000
# 4015                  0.681031           13  3.621212
# 602                   3.169942           10  4.268041
# 6836                  0.831634           11  3.487179
# 314                  11.159282            9  4.164134
# 6676                  1.076139            8  4.158537
# 1730                  2.753583            8  4.147727
# 2028                  2.145329            8  3.861842
# 2355                  2.768900            8  3.860825
# 7075                  0.946162            8  3.666667
# 7655                  0.235294            9  3.050000
# 6801                  0.526190            8  3.553571
# 6987                  0.195107            8  3.529412
# 2031                  2.576227            8  3.378641
# 6016                  0.867219            7  4.071429
# 8357                  0.666993            7  3.870968
# 6537                  1.429274            7  3.863636
# 5263                  1.485416            7  3.771930
#
#       normed_by_tags_movie_rating
# 257                    134.805834
# 1298                    20.924679
# 7166                     8.046956
# 4015                     6.938032
# 602                      5.875389
# 6836                     5.427381
# 314                      4.983720
# 6676                     4.229398
# 1730                     4.218405
# 2028                     3.927648
# 2355                     3.926613
# 7075                     3.729147
# 7655                     3.650302
# 6801                     3.614124
# 6987                     3.589553
# 2031                     3.436213
# 6016                     3.408843
# 8357                     3.241005
# 6537                     3.234867
# 5263                     3.158085
